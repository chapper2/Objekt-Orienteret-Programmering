# %%
class ScoreBoard():
    def __init__(self):
        self.scoreListe = []
        
    def holdTilføj(self,Hold):
        self.scoreListe.append(Hold)
    
    def printHoldNavn(self):
        for hold in self.scoreListe:
            print(hold.navn)
            
    def ændreScore(self, Hold):
        self.Hold.score += 1

class Hold():
    def __init__(self, navn):
        self.navn = navn
        score = 0

# %%
s1 = ScoreBoard()

h1 = Hold('EFB')

s1.holdTilføj(h1)
s1.printHoldNavn()
# Out:
# EFB
