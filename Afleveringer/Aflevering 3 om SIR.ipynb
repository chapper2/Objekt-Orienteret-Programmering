# %% [markdown]
# # Aflevering 3

# %% [markdown]
# ## SI-modellen

# %% [raw]
# Nedenfor ses et program, der simulerer en SI-model
#
# a) Kør programmet
#
# b) Indsæt kommentarer de steder i programmet, hvor der står 'skriv kommentar'
#
# c) Gennemgå de enkelte dele af programmet for at skabe en forståelse - ikke nødvendigt at skrive noget ned

# %%
import random
import math
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

class Person:
    def __init__(self, x, y, tilstand):
        self.x = x
        self.y = y
        self.tilstand = tilstand  # skriv kommentar

    def flyt(self):  # skriv kommentar
        vinkel = random.uniform(0, 2*math.pi)
        self.x += math.cos(vinkel) * 0.03
        self.y += math.sin(vinkel) * 0.03
        self.x = min(max(self.x, 0), 1)  # sikrer, at personen bliver inden for området
        self.y = min(max(self.y, 0), 1)  # som ovenfor

class Simulering:
    def __init__(self, antal, smitteRate, infektionsradius):
        self.personer = []
        self.smitteRate = smitteRate
        self.infektionsradius = infektionsradius
        for _ in range(antal):
            x, y = random.random(), random.random()  # skriv kommentar
            if random.random() < 0.02:  # skriv kommentar
                tilstand = 'inficeret' 
            else:
                tilstand = 'smittelig'
            self.personer.append(Person(x, y, tilstand))  # skriv kommentar

    def step(self):
        for p in self.personer:  # skriv kommentar
            p.flyt()

        for p in self.personer:  # skriv kommentar
            if p.tilstand == 'smittelig':
                for q in self.personer:
                    if q.tilstand == 'inficeret':
                        distance = math.dist((p.x, p.y), (q.x, q.y))  # bestemmer afstanden mellem de to personer
                        if distance < self.infektionsradius and random.random() < self.smitteRate:
                            p.tilstand = 'inficeret' # skriv kommentar
                            break

class Visualisering:
    def __init__(self, sim):
        self.sim = sim
        self.fig, self.ax = plt.subplots(figsize=(6,6))
        self.historik = []

    def opdater(self, frame):
        self.sim.step()
        self.ax.clear()
        
        xS = []
        yS = []
        xI = []
        yI = []
   
        for p in self.sim.personer:
            if p.tilstand == 'smittelig':
                xS.append(p.x)
                yS.append(p.y)
            if p.tilstand == 'inficeret':
                xI.append(p.x)
                yI.append(p.y)

        self.historik.append([len(xS), len(xI)])

        self.ax.scatter(xS, yS, color='blue', label='smittelig', s=10)  # skriv kommentar
        self.ax.scatter(xI, yI, color='red', label='inficeret', s=10)  # skriv kommentar

        self.ax.set_xlim(0, 1)
        self.ax.set_ylim(0, 1)
        self.ax.set_title('SI-smittemodel')
        self.ax.legend(loc='upper right')

    def animer(self):
        self.anim = FuncAnimation(self.fig, self.opdater, frames=300, interval=50)
        plt.show()

sim = Simulering(antal=400, smitteRate=0.25, infektionsradius=0.04)
vis = Visualisering(sim)
vis.animer()

# %% [raw]
# Nedenfor ses en måde at visualisere modellen på
#
# d) Kør koden og prøv at forstå de enkelte sætninger

# %%
S = []
I = []
for h in vis.historik:
    S.append(h[0])
    I.append(h[1])
plt.figure(figsize=(10, 6))
plt.plot(S, label='S smittelige', color='blue')
plt.plot(I, label='I inficerede', color='red')
plt.xlabel('Tid (dage)')
plt.ylabel('Antal personer')
plt.title('SI-model')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## SIR-modellen

# %% [raw]
# Nedenfor ses en kopi af ovenstående SI-model, og det er nu meningen, at I skal udvide den, så det bliver en SIR-model
#
# e) Tilføj parameteren raskRate til klassen Simulering
#
# f) Tilføj i step-funktionen muligheden for at blive rask
#
# g) Sørg for i funktionen opdater, at der sker en opdatering af antallet af raske, dvs tilføj lister xR og yR med de raske personer, så de kan afbildes med grøn
#
# h) Kør SIR-modellen og tjek, at det fungerer
#
# i) Kør modellen med forskellige værdier

# %%
import random
import math
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

class Person:
    def __init__(self, x, y, tilstand):
        self.x = x
        self.y = y
        self.tilstand = tilstand  # skriv kommentar

    def flyt(self):  # skriv kommentar
        vinkel = random.uniform(0, 2*math.pi)
        self.x += math.cos(vinkel) * 0.03
        self.y += math.sin(vinkel) * 0.03
        self.x = min(max(self.x, 0), 1)  # sikrer, at personen bliver inden for området
        self.y = min(max(self.y, 0), 1)  # som ovenfor

class Simulering:
    def __init__(self, antal, smitteRate, infektionsradius):
        self.personer = []
        self.smitteRate = smitteRate
        self.infektionsradius = infektionsradius
        for _ in range(antal):
            x, y = random.random(), random.random()  # skriv kommentar
            if random.random() < 0.02:  # skriv kommentar
                tilstand = 'inficeret' 
            else:
                tilstand = 'smittelig'
            self.personer.append(Person(x, y, tilstand))  # skriv kommentar

    def step(self):
        for p in self.personer:  # skriv kommentar
            p.flyt()

        for p in self.personer:  # skriv kommentar
            if p.tilstand == 'smittelig':
                for q in self.personer:
                    if q.tilstand == 'inficeret':
                        distance = math.dist((p.x, p.y), (q.x, q.y))  # bestemmer afstanden mellem de to personer
                        if distance < self.infektionsradius and random.random() < self.smitteRate:
                            p.tilstand = 'inficeret' # skriv kommentar
                            break

class Visualisering:
    def __init__(self, sim):
        self.sim = sim
        self.fig, self.ax = plt.subplots(figsize=(6,6))
        self.historik = []

    def opdater(self, frame):
        self.sim.step()
        self.ax.clear()
        
        xS = []
        yS = []
        xI = []
        yI = []
   
        for p in self.sim.personer:
            if p.tilstand == 'smittelig':
                xS.append(p.x)
                yS.append(p.y)
            if p.tilstand == 'inficeret':
                xI.append(p.x)
                yI.append(p.y)

        self.historik.append([len(xS), len(xI)])

        self.ax.scatter(xS, yS, color='blue', label='smittelig', s=10)  # skriv kommentar
        self.ax.scatter(xI, yI, color='red', label='inficeret', s=10)  # skriv kommentar

        self.ax.set_xlim(0, 1)
        self.ax.set_ylim(0, 1)
        self.ax.set_title('SI-smittemodel')
        self.ax.legend(loc='upper right')

    def animer(self):
        self.anim = FuncAnimation(self.fig, self.opdater, frames=300, interval=50)
        plt.show()

sim = Simulering(antal=400, smitteRate=0.25, infektionsradius=0.04)
vis = Visualisering(sim)
vis.animer()

# %% [raw]
# Nedenfor ses en kopi af cellen, hvor grafikken for SI-modellen blev dannet
#
# j) Udvid koden nedenfor, så de raske også er med
#
# k) Tjek, at det fungerer

# %%
S = []
I = []
for h in vis.historik:
    S.append(h[0])
    I.append(h[1])
plt.figure(figsize=(10, 6))
plt.plot(S, label='S smittelige', color='blue')
plt.plot(I, label='I inficerede', color='red')
plt.xlabel('Tid (dage)')
plt.ylabel('Antal personer')
plt.title('SI-model')
plt.legend()
plt.grid(True)
plt.show()
