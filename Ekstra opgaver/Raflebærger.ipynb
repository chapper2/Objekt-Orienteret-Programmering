# %% [raw]
# Opgave 1
#
# a) Lav et program i Python, der kan kaste med én terning fire gange og bestemme summen af øjnene - hjælp: du skal lave en klasse Terning
#
# b) Lav et program i Python, der kan kaste med fire terninger på én gang og bestemme summen af øjnene - hjælp: du skal bruge samme klasse Terning som i a)
#
# c) Giver det mening at omtale ovenstående objektorienterede programmering som agentbaseret modellering?
#     Nej, dette er ren objektorienteret da vi opretter en specifik instans af vores objekt, som ikke kan inteagere med dens omverden.
#
# d) Lav en Scratch-version af b) med brug af kloner

# %%
import random

class Terning():
    def __init__(self):
        self.antalTerninger = int(input('indtast antallet af terninger du vil slå med'))
        self.antalØjne = int(input('indtast antal øjne terningerne skal have'))
        self.øjeListe = []
        
        
        
    def terningeKast(self):
        for i in range(self.antalTerninger):
            resultat = random.randint(1,self.antalØjne)
            self.øjeListe.append(resultat)
        
        print(f'Du har slået med terningerne {self.antalTerninger} gange, og fået følgende øjne ud: {self.øjeListe}, summen af øjnene er {sum(self.øjeListe)}')

# %%
terning1 = Terning()

terning1.terningeKast()
# Out:
# Du har slået med terningerne 5 gange, og fået følgende øjne ud: [1, 3, 4, 1, 5], summen af øjnene er 14

# %%
import random

class Terning2():
    def __init__(self):
        self.øjne = 0
    
    def ruld(self):
       self.øjne = random.randint(1,6)
       return self.øjne
       

class rafleBærger():
    def __init__(self, antalTerninger):
        self.antalTerninger = antalTerninger
        self.bærger = []
        
    def rafle(self):
        for i in range(self.antalTerninger): #Her håndtere raflebærgeret at oprette terninger
            terning = Terning2()
            self.bærger.append(terning.ruld())
            print(f'Terning nr: {i+1} rullede {self.bærger[i]}')
    
    
    #print(f'Antallet af terninger der er raflet: {self.antalTerninger} og øjnene blev')

# %%
raflekop = rafleBærger(50)

raflekop.rafle()
# Out:
# Terning nr: 1 rullede 4
# Terning nr: 2 rullede 6
# Terning nr: 3 rullede 1
# Terning nr: 4 rullede 3
# Terning nr: 5 rullede 1
# Terning nr: 6 rullede 3
# Terning nr: 7 rullede 3
# Terning nr: 8 rullede 3
# Terning nr: 9 rullede 2
# Terning nr: 10 rullede 4
# Terning nr: 11 rullede 1
# Terning nr: 12 rullede 4
# Terning nr: 13 rullede 3
# Terning nr: 14 rullede 6
# Terning nr: 15 rullede 1
# Terning nr: 16 rullede 4
# Terning nr: 17 rullede 2
# Terning nr: 18 rullede 1
# Terning nr: 19 rullede 5
# Terning nr: 20 rullede 4
# Terning nr: 21 rullede 5
# Terning nr: 22 rullede 3
# Terning nr: 23 rullede 3
# Terning nr: 24 rullede 6
# Terning nr: 25 rullede 3
# Terning nr: 26 rullede 6
# Terning nr: 27 rullede 3
# Terning nr: 28 rullede 3
# Terning nr: 29 rullede 1
# Terning nr: 30 rullede 6
# Terning nr: 31 rullede 5
# Terning nr: 32 rullede 1
# Terning nr: 33 rullede 1
# Terning nr: 34 rullede 4
# Terning nr: 35 rullede 3
# Terning nr: 36 rullede 4
# Terning nr: 37 rullede 6
# ...
